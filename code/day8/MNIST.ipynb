# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train = pd.read_csv("train.csv")

# %%
train_vals = train.drop("label", axis=1)
train_labels = train["label"]

# %%
def get_vector_from_index(df, index):
    return df.iloc[[index]].values

def show_vector(vector):
    plt.matshow(vector.reshape(28, 28))

# %%
for v in range(5):
    show_vector(get_vector_from_index(train_vals, v))

# %%
grouped = train.groupby("label").sum()

# %%
for i in range(10):
    show_vector(get_vector_from_index(grouped, i))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import train_test_split

train_data, validation_data = train_test_split(train,test_size=0.1,random_state=198)
X_train, y_train = train_data.drop("label", axis=1), train_data["label"]
X_valid, y_valid = validation_data.drop("label", axis=1), validation_data["label"]
print(X_train.shape, X_valid.shape)

# %%
import time

clf = LogisticRegression()
a = time.clock()
clf.fit(X_train.as_matrix()[:4200], y_train.as_matrix()[:4200])
pred = clf.predict(X_valid)
b = time.clock()
print(b - a)
print(np.mean(pred == y_valid))

# %% [markdown]
# # *k*-nearest neighbors algorithm (kNN)
#
#
#
# An object is classified by a majority vote of its neighbors, and is assigned to the class most common among its k nearest neighbors.
#
# http://yann.lecun.com/exdb/mnist/
#
#
# ![texte](https://upload.wikimedia.org/wikipedia/commons/e/e7/KnnClassification.svg)
# ![texte](http://image.slidesharecdn.com/machinelearningintroduction-120427064838-phpapp01/95/machine-learning-introduction-14-638.jpg?cb=1389174073)

# %%
from sklearn.neighbors import KNeighborsClassifier

train_data, validation_data = train_test_split(train,test_size=0.1,random_state=198)
X_train, y_train = train_data.drop("label", axis=1), train_data["label"]
X_valid, y_valid = validation_data.drop("label", axis=1), validation_data["label"]

# %%
clf = KNeighborsClassifier(n_neighbors = 5)
              
a = time.clock()
clf.fit(X_train.as_matrix()[:1000], y_train.as_matrix()[:1000])
pred = clf.predict(X_valid)
pred2 = clf.predict(X_train.as_matrix()[:1000])
b = time.clock()
print("{0:.1f} Seconds to predict based on 1000 training examples".format(b-a))
print("{0:.2f}% validation accuracy".format(np.mean(pred == y_valid) * 100))

# %%
clf = KNeighborsClassifier(n_neighbors=5)
              
a = time.clock()
clf.fit(X_train, y_train)
pred = clf.predict(X_valid)
b = time.clock()
print("{} Seconds to predict based on all training examples".format(b-a))
print("{0:.2f}% validation accuracy".format(np.mean(pred == y_valid) * 100))

# %%
# test = pd.read_csv("test.csv")

# clf = KNeighborsClassifier(n_neighbors=5)
# clf.fit(train_vals, train_labels)

# all_pred = []

# for batch in np.arange(0, 28000, 100):
#     a = time.clock()
#     pred = clf.predict(test[batch:batch+100])
#     all_pred.append(list(pred))
#     b = time.clock()
#     print(batch/100, b - a)
# Out:
# 0.0 6.912264
# 1.0 6.905853999999998
# 2.0 7.06617
# 3.0 6.866946999999996
# 4.0 7.275289999999998
# 5.0 7.075614000000002
# 6.0 7.812871999999999
# 7.0 7.955501999999996
# 8.0 7.2994839999999925
# 9.0 7.0289789999999925
# 10.0 6.994269000000003
# 11.0 7.748196000000007
# 12.0 7.39667399999999
# 13.0 7.1884319999999775
# 14.0 6.980270999999988
# 15.0 7.034767000000016
# 16.0 6.94055800000001
# 17.0 7.108453999999995
# 18.0 7.0016880000000015
# 19.0 6.903988999999996
# 20.0 7.008961999999997
# 21.0 7.118580999999978
# 22.0 7.1651119999999935
# 23.0 7.6617020000000196
# 24.0 7.6583300000000065
# 25.0 7.153158999999988
# 26.0 6.862601000000012
# 27.0 6.905158999999998
# 28.0 7.273227999999989
# 29.0 7.105502999999999
# 30.0 7.089127999999988
# 31.0 6.931588999999974
# 32.0 6.969874000000004
# 33.0 7.130586999999991
# 34.0 7.0228629999999725
# 35.0 6.944854000000021
# 162.0 8.349312999999938
# 163.0 8.191974999999957
# 164.0 8.134281999999985
# 165.0 8.025525000000016
# 166.0 8.112710000000106
# 167.0 8.764982000000145
# 168.0 8.772979000000078
# 169.0 8.237461999999823
# 170.0 7.997260000000097
# 171.0 8.21981599999981
# 172.0 8.235638999999992
# 173.0 8.098348999999871
# 174.0 8.123985999999832
# 175.0 8.11242900000002
# 176.0 8.233369999999923
# 177.0 7.980819999999994
# 178.0 8.373219999999947
# 179.0 8.125556000000188
# 180.0 7.72003299999983
# 181.0 7.394291000000067
# 182.0 7.365886000000046
# 183.0 7.499906999999894
# 184.0 7.826076000000057
# 185.0 7.667543000000023
# 186.0 8.209914000000026
# 187.0 8.48168399999986
# 188.0 8.4380799999999
# 189.0 8.288256000000047
# 190.0 8.505840000000035
# 191.0 8.2509849999999
# 192.0 8.393121999999948
# 193.0 8.067340999999942
# 194.0 8.074303999999984
# 195.0 8.218082000000095
# 196.0 7.403935999999931
# 197.0 7.300852000000077
# 198.0 7.192826000000196
# 199.0 7.66619199999991
# 200.0 7.815382
# 201.0 8.281400000000076
# 202.0 8.360856000000013
# 203.0 8.241700000000037
# 204.0 8.261541999999963
# 205.0 8.3757149999999
# 206.0 8.425436999999874
# 207.0 8.362242999999808
# 208.0 8.54030899999998
# 209.0 8.556104000000005
# 210.0 8.441683999999896
# 211.0 8.062669000000142
# 212.0 8.489172000000053
# 213.0 8.166626000000178
# 214.0 8.232418000000052
# 215.0 8.136162000000013
# 216.0 8.423767999999882
# 217.0 8.305849999999964
# 218.0 8.198609000000033
# 219.0 8.64093899999989
# 220.0 8.2559040000001
# 221.0 8.332405999999992
# 222.0 8.366876999999931
# 223.0 8.4489880000001
# 224.0 8.232401000000209
# 225.0 8.262318999999934
# 226.0 8.20263900000009
# 227.0 8.132325999999921
# 228.0 8.4164209999999
# 229.0 8.258813000000146
# 230.0 8.44980499999997
# 231.0 8.533003000000008
# 232.0 8.128594000000021
# 233.0 8.358890999999858
# 234.0 8.272253999999975
# 235.0 8.09674199999995
# 236.0 8.058909999999969
# 237.0 8.220992000000024
# 238.0 8.243919000000005
# 239.0 8.175122999999985
# 240.0 8.064761999999973
# 241.0 8.248331999999891
# 242.0 8.086266999999907
# 243.0 8.15255400000001
# 244.0 8.16639699999996
# 245.0 8.303407000000107
# 246.0 8.227028999999902
# 247.0 8.109909000000016
# 248.0 8.032517999999982
# 249.0 8.230823999999984
# 250.0 8.187376000000086
# 251.0 8.065421999999899
# 252.0 8.04694100000006
# 253.0 8.18405400000006
# 254.0 8.068853999999874
# 255.0 8.079861999999821
# 256.0 8.049641999999949
# 257.0 8.137316999999939
# 258.0 8.123792000000094
# 259.0 8.13109099999997
# 260.0 8.097755000000006
# 261.0 8.026178000000073
# 262.0 8.722256000000016
# 263.0 8.09706099999994
# 264.0 8.042918999999983
# 265.0 8.067806000000019
# 266.0 7.399909999999636
# 267.0 7.441522000000077
# 268.0 7.53503899999987
# 269.0 7.726595999999972
# 270.0 7.7901710000001
# 271.0 7.679802999999993
# 272.0 8.047647000000325
# 273.0 8.78398100000004
# 274.0 9.035792000000129
# 275.0 8.7910609999999
# 276.0 8.433558000000176
# 277.0 8.297770000000128
# 278.0 8.23661200000015
# 279.0 8.287499999999909

# %%
# real_pred = []
# for lst in all_pred:
#     real_pred.extend(lst)

# %%
# with open("sub.csv", 'w') as fp:
#     fp.write("ImageId,Label\n")
#     for i in range(len(real_pred)):
#         fp.write(str(i+1) + "," + str(real_pred[i]) + "\n")
